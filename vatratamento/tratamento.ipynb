# %%
import pandas as pd
import numpy as np
import os

# %%
caminho_xlsx = r'C:\Users\Robert\Documents\Python\base_de_dados\relatorio.xlsx'

# %%
try:
    df_bruto = pd.read_excel(caminho_xlsx, header=None, engine='openpyxl')
    df_bruto.drop(df_bruto.index[:10], inplace=True)
    df_bruto.dropna(how='all', inplace=True)
    df_bruto.reset_index(drop=True, inplace=True)
    
    # Vamos usar um método mais seguro que não depende da posição exata.
    # Encontramos o índice da primeira ocorrência de "Tipo" e começamos a partir daí.
    primeiro_tipo_idx = df_bruto[df_bruto[0] == 'Tipo'].index[0]
    df_bruto = df_bruto.iloc[primeiro_tipo_idx:].copy()
    df_bruto.reset_index(drop=True, inplace=True)

    print("Arquivo lido e preparado.")
    print("DataFrame pronto para o loop:")

except Exception as e:
    print(f"Ocorreu um erro na leitura: {e}")
    df_bruto = pd.DataFrame()

df_bruto.head(5)
# Out:
# Arquivo lido e preparado.
# DataFrame pronto para o loop:
#        0         1                         2            3    4   \
# 0    Tipo       NaN                       NaN          NaN  NaN
# 1       1       NaN                       NaN          NaN  NaN
# 2    Item  Situação                 Descrição  Complemento   UM
# 3  109041       NaN  BOVINUCLEO BEZERROS 30KG          NaN   SC
# 4    Tipo       NaN                       NaN          NaN  NaN
#
#                 5    6           7                    8             9      10  \
# 0             Nome  NaN         NaN                  NaN           NaN  Grupo
# 1  PRODUTO ACABADO  NaN         NaN                  NaN           NaN     10
# 2           Origem  IPI  Cl. Fiscal        Data Cadastro  Data Inativo    NaN
# 3                C    0    23099090  2017-07-24 00:00:00           NaN    NaN
# 4             Nome  NaN         NaN                  NaN           NaN  Grupo
#
#    11  12  13  14            15
# 0 NaN NaN NaN NaN          Nome
# 1 NaN NaN NaN NaN  RACAO BOVINO
# 2 NaN NaN NaN NaN           NaN
# 3 NaN NaN NaN NaN           NaN
# 4 NaN NaN NaN NaN          Nome

# %%
# --- 2. IMPLEMENTAÇÃO FINAL COM BUSCA ROBUSTA ---

memoria_categoria = {
    'Tipo': None, 'Nome_Tipo': None,
    'Grupo': None, 'Nome_Grupo': None
}
dados_finais = []

if not df_bruto.empty:
    for index, row in df_bruto.iterrows():
        try:
            # --- REGRA 1: É A LINHA DE CABEÇALHO "Tipo"? ---
            if str(row.iloc[0]).strip() == 'Tipo':
                
                if index + 1 < len(df_bruto):
                    linha_de_valores = df_bruto.iloc[index + 1]
                    
                    # Captura os Nomes, que são estáveis
                    nome_tipo_atual = linha_de_valores.iloc[5]
                    nome_grupo_atual = linha_de_valores.iloc[15]
                    
                    # --- LÓGICA DE BUSCA PELO VIZINHO ---
                    tipo_atual = None
                    # Procura o valor do Tipo à esquerda do Nome do Tipo
                    for i in range(4, -1, -1): # Itera das colunas 4 a 0
                        val = pd.to_numeric(linha_de_valores.iloc[i], errors='coerce')
                        if pd.notna(val):
                            tipo_atual = val
                            break # Encontrou, pode parar de procurar

                    grupo_atual = None
                    # Procura o valor do Grupo à esquerda do Nome do Grupo
                    for i in range(14, 5, -1): # Itera das colunas 14 a 6
                        val = pd.to_numeric(linha_de_valores.iloc[i], errors='coerce')
                        if pd.notna(val):
                            grupo_atual = val
                            break # Encontrou, pode parar de procurar
                    
                    # Atualiza a memória com tudo que foi encontrado
                    memoria_categoria['Tipo'] = tipo_atual
                    memoria_categoria['Nome_Tipo'] = nome_tipo_atual
                    memoria_categoria['Grupo'] = grupo_atual
                    memoria_categoria['Nome_Grupo'] = nome_grupo_atual
                    
                    print(f"--- MEMÓRIA ATUALIZADA: Tipo {tipo_atual}, Grupo {grupo_atual} ---")
                continue

            # --- REGRA 2: É UMA LINHA DE DADOS DE ITEM? ---
            item_id = pd.to_numeric(row.iloc[0], errors='coerce')
            
            if pd.notna(item_id) and pd.notna(row.iloc[2]):
                dados_finais.append({
                    'Item': int(item_id),
                    'Descrição': str(row.iloc[2]),
                    'Tipo': memoria_categoria['Tipo'],
                    'Nome_Tipo': memoria_categoria['Nome_Tipo'],
                    'Grupo': memoria_categoria['Grupo'],
                    'Nome_Grupo': memoria_categoria['Nome_Grupo']
                })
        except (IndexError, TypeError, ValueError):
            continue

# --- 3. CRIAÇÃO DO DATAFRAME FINAL ---
df_final = pd.DataFrame(dados_finais)
if not df_final.empty:
    for col in ['Item', 'Tipo', 'Grupo']:
        df_final[col] = pd.to_numeric(df_final[col], errors='coerce').astype('Int64')

# --- EXIBIÇÃO DO RESULTADO ---
print("\n--- DataFrame Final Estruturado ---")
display(df_final)
# Out:
# --- MEMÓRIA ATUALIZADA: Tipo 1, Grupo 10 ---
# --- MEMÓRIA ATUALIZADA: Tipo 1, Grupo 26 ---
# --- MEMÓRIA ATUALIZADA: Tipo 1, Grupo 41 ---
# --- MEMÓRIA ATUALIZADA: Tipo 1, Grupo 87 ---
# --- MEMÓRIA ATUALIZADA: Tipo 1, Grupo 996 ---
# --- MEMÓRIA ATUALIZADA: Tipo 1, Grupo 998 ---
# --- MEMÓRIA ATUALIZADA: Tipo 1, Grupo 999 ---
# --- MEMÓRIA ATUALIZADA: Tipo 2, Grupo 18 ---
# --- MEMÓRIA ATUALIZADA: Tipo 2, Grupo 70 ---
# --- MEMÓRIA ATUALIZADA: Tipo 3, Grupo 47 ---
# --- MEMÓRIA ATUALIZADA: Tipo 4, Grupo 86 ---
# --- MEMÓRIA ATUALIZADA: Tipo 4, Grupo 87 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 1 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 2 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 6 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 8 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 9 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 11 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 12 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 13 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 15 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 16 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 17 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 19 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 20 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 22 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 28 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 30 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 31 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 32 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 34 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 35 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 36 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 37 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 38 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 40 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 41 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 42 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 43 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 44 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 45 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 46 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 55 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 60 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 62 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 67 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 68 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 69 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 71 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 76 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 78 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 80 ---
# --- MEMÓRIA ATUALIZADA: Tipo 5, Grupo 999 ---
# --- MEMÓRIA ATUALIZADA: Tipo 6, Grupo 2 ---
# --- MEMÓRIA ATUALIZADA: Tipo 6, Grupo 7 ---
# --- MEMÓRIA ATUALIZADA: Tipo 6, Grupo 8 ---
# --- MEMÓRIA ATUALIZADA: Tipo 6, Grupo 14 ---
# --- MEMÓRIA ATUALIZADA: Tipo 6, Grupo 26 ---
# --- MEMÓRIA ATUALIZADA: Tipo 6, Grupo 27 ---
# --- MEMÓRIA ATUALIZADA: Tipo 6, Grupo 29 ---
# --- MEMÓRIA ATUALIZADA: Tipo 6, Grupo 33 ---
# --- MEMÓRIA ATUALIZADA: Tipo 6, Grupo 73 ---
# --- MEMÓRIA ATUALIZADA: Tipo 6, Grupo 87 ---
# --- MEMÓRIA ATUALIZADA: Tipo 6, Grupo 996 ---
# --- MEMÓRIA ATUALIZADA: Tipo 7, Grupo 5 ---
# --- MEMÓRIA ATUALIZADA: Tipo 7, Grupo 31 ---
# --- MEMÓRIA ATUALIZADA: Tipo 8, Grupo 19 ---
# --- MEMÓRIA ATUALIZADA: Tipo 8, Grupo 20 ---
# --- MEMÓRIA ATUALIZADA: Tipo 8, Grupo 34 ---
# --- MEMÓRIA ATUALIZADA: Tipo 8, Grupo 41 ---
# --- MEMÓRIA ATUALIZADA: Tipo 8, Grupo 71 ---
# --- MEMÓRIA ATUALIZADA: Tipo 9, Grupo 999 ---
# --- MEMÓRIA ATUALIZADA: Tipo 10, Grupo 2 ---
# --- MEMÓRIA ATUALIZADA: Tipo 10, Grupo 6 ---
# --- MEMÓRIA ATUALIZADA: Tipo 11, Grupo 57 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 1 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 2 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 3 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 5 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 6 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 8 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 9 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 11 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 12 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 13 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 14 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 15 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 16 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 17 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 19 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 20 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 21 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 22 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 26 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 27 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 28 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 30 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 31 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 32 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 33 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 34 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 35 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 36 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 37 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 38 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 39 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 40 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 41 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 42 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 44 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 45 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 46 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 50 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 51 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 55 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 56 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 60 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 62 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 65 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 66 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 67 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 68 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 69 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 70 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 71 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 75 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 76 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 78 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 80 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 87 ---
# --- MEMÓRIA ATUALIZADA: Tipo 12, Grupo 996 ---
# --- MEMÓRIA ATUALIZADA: Tipo 13, Grupo 35 ---
# --- MEMÓRIA ATUALIZADA: Tipo 14, Grupo 57 ---
# --- MEMÓRIA ATUALIZADA: Tipo 15, Grupo 57 ---
# --- MEMÓRIA ATUALIZADA: Tipo 16, Grupo 2 ---
# --- MEMÓRIA ATUALIZADA: Tipo 16, Grupo 6 ---
# --- MEMÓRIA ATUALIZADA: Tipo 16, Grupo 11 ---
# --- MEMÓRIA ATUALIZADA: Tipo 16, Grupo 12 ---
# --- MEMÓRIA ATUALIZADA: Tipo 16, Grupo 34 ---
# --- MEMÓRIA ATUALIZADA: Tipo 16, Grupo 60 ---
# --- MEMÓRIA ATUALIZADA: Tipo 16, Grupo 68 ---
# --- MEMÓRIA ATUALIZADA: Tipo 21, Grupo 3 ---
# --- MEMÓRIA ATUALIZADA: Tipo 21, Grupo 11 ---
# --- MEMÓRIA ATUALIZADA: Tipo 21, Grupo 12 ---
# --- MEMÓRIA ATUALIZADA: Tipo 21, Grupo 13 ---
# --- MEMÓRIA ATUALIZADA: Tipo 21, Grupo 15 ---
# --- MEMÓRIA ATUALIZADA: Tipo 21, Grupo 16 ---
# --- MEMÓRIA ATUALIZADA: Tipo 21, Grupo 32 ---
# --- MEMÓRIA ATUALIZADA: Tipo 21, Grupo 38 ---
# --- MEMÓRIA ATUALIZADA: Tipo 21, Grupo 60 ---
# --- MEMÓRIA ATUALIZADA: Tipo 21, Grupo 68 ---
# --- MEMÓRIA ATUALIZADA: Tipo 21, Grupo 76 ---
# --- MEMÓRIA ATUALIZADA: Tipo 21, Grupo 78 ---
# --- MEMÓRIA ATUALIZADA: Tipo 21, Grupo 80 ---
# --- MEMÓRIA ATUALIZADA: Tipo 22, Grupo 7 ---
# --- MEMÓRIA ATUALIZADA: Tipo 22, Grupo 14 ---
# --- MEMÓRIA ATUALIZADA: Tipo 22, Grupo 27 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 8 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 12 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 16 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 21 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 28 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 31 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 43 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 48 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 49 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 50 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 51 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 52 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 53 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 56 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 57 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 58 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 59 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 61 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 63 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 64 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 65 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 72 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 74 ---
# --- MEMÓRIA ATUALIZADA: Tipo 25, Grupo 75 ---
#
# --- DataFrame Final Estruturado ---
#          Item                                          Descrição  Tipo  \
# 0      109041                           BOVINUCLEO BEZERROS 30KG     1
# 1       79000                      FARINHA DE VISCERAS DE FRANGO     1
# 2       79003                                   RESÍDUOS DE PENA     1
# 3       79004                                 RESÍDUOS DE SANGUE     1
# 4         193  BOBINA COXA E SOBRECOXA RESFRIADA 530 MM X 350...     1
# ...       ...                                                ...   ...
# 17460  120325          PRESTACAO SERVICO DE INSPECAO DO DIGESTOR    25
# 17461  120579  MODULO CEP CONTROLE ESTATISTICO DE PROCESSOS S...    25
# 17462  120578                     MODULO DE ESTOQUE SO AUTOMACAO    25
# 17463  120577             MODULO DE RASTREABILIDADE SO AUTOMACAO    25
# 17464  120580  SYSFEED - SISTEMA DE DOSAGEM DE LIQUIDOS E SOL...    25
#
#              Nome_Tipo  Grupo  \
# 0      PRODUTO ACABADO     10
# 1      PRODUTO ACABADO     26
# 2      PRODUTO ACABADO     26
# 3      PRODUTO ACABADO     26
# 4      PRODUTO ACABADO     41
# ...                ...    ...
# 17460         SERVICOS     74
# 17461         SERVICOS     75
# 17462         SERVICOS     75
# 17463         SERVICOS     75
# 17464         SERVICOS     75
#
#                                              Nome_Grupo
# 0                                          RACAO BOVINO
# 1                                           SUB PRODUTO
# 2                                           SUB PRODUTO
# 3                                           SUB PRODUTO
# 4                                    EMBALAGEM PRIMARIA
# ...                                                 ...
# 17460                   SERVICOS DE INSPECAO/CALIBRACAO
# 17461  SERVICO CONTRATACAO DE SOFTWARE FABRICA DE RACAO
# 17462  SERVICO CONTRATACAO DE SOFTWARE FABRICA DE RACAO
# 17463  SERVICO CONTRATACAO DE SOFTWARE FABRICA DE RACAO
# 17464  SERVICO CONTRATACAO DE SOFTWARE FABRICA DE RACAO
#
# [17465 rows x 6 columns]

# %%
caminho_salvamento = r'C:\Users\Robert\Documents\Python\base_de_dados'
caminho_final = os.path.join(caminho_salvamento, 'd_produtos_almoxarifado.xlsx')

df_final.to_excel(caminho_final, index=False)
